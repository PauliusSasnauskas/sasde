# %%
from eq2 import config
from main import run

# %%
run(config)
# Out:
# 14:47:19.434 [INFO] Unable to initialize backend 'tpu_driver': NOT_FOUND: Unable to find driver in registry given worker:
# 14:47:19.435 [INFO] Unable to initialize backend 'gpu': NOT_FOUND: Could not find registered platform with name: "cuda". Available platform names are: Interpreter Host
# 14:47:19.436 [INFO] Unable to initialize backend 'tpu': INVALID_ARGUMENT: TpuPlatform is not available.
# 14:47:19.734 [INFO] Constructed symbolic model
# 14:47:19.769 [INFO] Integrated
# 14:47:26.193 [INFO] Lambdified
# 14:47:26.194 [INFO] Constructed JAXified model
# 14:47:27.470 [INFO] W₀ = [ 0.0006,  0.0005,  0.0003,  0.0006,  0.0004,  0.0007,  0.0005,  0.0004,  0.0001,  0.0006,  0.0005,  0.0001,  0.0002,  0.0008,  0.0001,  0.0009,  0.0006,  0.0008,  0.0003,  0.0005,  0.0004,  0.0009,  0.0000,  0.0006,  0.0007,  0.0006,  0.0010,  0.0006,  0.0004,  0.0002,  0.0007,  0.0007,  0.0004,  0.0008,  0.0006,  0.0005,  0.0008,  0.0002,  0.0000,  0.0000]
# ...
